# %%
import cil
from cil.utilities.display import show2D
import sirf.STIR as pet
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
res_path = '/home/jovyan/Hackathon-000-Stochastic-Hydra/Hydra_Example/results'

# %%
x = pet.ImageData('{}/{}'.format(res_path,'solution.hv'))
# Out:
# WARNING: RadioNuclideDB::get_radionuclide: unknown modality. Returning "unknown" radionuclide.

# %%
show2D(x)

# %%
obj = np.load('{}/{}'.format(res_path,'objective.npy'))

# %%
plt.semilogy(obj)
